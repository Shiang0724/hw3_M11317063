# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.functional import to_pil_image
from dataset import get_loaders
from PIL import Image
import segmentation_models_pytorch as smp

# ------------------------------
# 1. 損失與評估函數
# ------------------------------
def dice_loss(pred, target, eps=1e-6):
    pred = torch.sigmoid(pred)
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum()
    return 1 - (2. * intersection + eps) / (union + eps)

def mixed_loss(pred, target):
    bce = nn.BCEWithLogitsLoss()(pred, target)
    return bce + dice_loss(pred, target)

def compute_iou(preds, masks, threshold=0.5):
    preds = (torch.sigmoid(preds) > threshold).float()
    intersection = (preds * masks).sum(dim=(1, 2, 3))
    union = ((preds + masks) > 0).float().sum(dim=(1, 2, 3))
    return (intersection / (union + 1e-6)).mean().item()

def evaluate_prediction_error(preds, masks, px_per_cm=72):
    preds = (torch.sigmoid(preds) > 0.5).float()
    errors = []
    for i in range(preds.size(0)):
        pred_coords = torch.nonzero(preds[i, 0], as_tuple=False)
        true_coords = torch.nonzero(masks[i, 0], as_tuple=False)
        if len(pred_coords) == 0 or len(true_coords) == 0:
            continue
        pred_y = pred_coords[:, 0].float().mean()
        true_y = true_coords[:, 0].float().mean()
        errors.append(torch.abs(pred_y - true_y).item())

    if not errors:
        return 0, 0, 0
    mean_err = np.mean(errors)
    acc_0_5cm = np.mean(np.array(errors) <= (0.5 * px_per_cm)) * 100
    acc_1_0cm = np.mean(np.array(errors) <= (1.0 * px_per_cm)) * 100
    return mean_err, acc_0_5cm, acc_1_0cm

# ------------------------------
# 2. 訓練與預測流程（使用預訓練 Unet）
# ------------------------------
device = 'cuda' if torch.cuda.is_available() else 'cpu'
os.makedirs("checkpoints/unet", exist_ok=True)

folds = ['Fold1', 'Fold2', 'Fold3', 'Fold4', 'Fold5']
for fold in folds:
    print(f"=== 開始訓練 {fold} ===")
    model = smp.Unet(
        encoder_name="resnet34",
        encoder_weights="imagenet",
        in_channels=3,
        classes=1
    ).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    train_loader, val_loader = get_loaders('processed_data', fold, batch_size=4)

    best_val_iou = 0
    patience = 30
    early_stop_counter = 0

    for epoch in range(100):
        model.train()
        total_loss = 0
        for imgs, masks in train_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            outputs = model(imgs)
            loss = mixed_loss(outputs, masks)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 驗證
        model.eval()
        val_iou = val_err = acc_0_5cm = acc_1_0cm = 0
        with torch.no_grad():
            for imgs, masks in val_loader:
                imgs, masks = imgs.to(device), masks.to(device)
                outputs = model(imgs)
                val_iou += compute_iou(outputs, masks)
                mean_err, a05, a10 = evaluate_prediction_error(outputs, masks)
                val_err += mean_err
                acc_0_5cm += a05
                acc_1_0cm += a10

        val_iou /= len(val_loader)
        val_err /= len(val_loader)
        acc_0_5cm /= len(val_loader)
        acc_1_0cm /= len(val_loader)

        print(f"[{fold} - Epoch {epoch+1}] Loss: {total_loss:.2f} | IOU: {val_iou:.4f} | 平均誤差: {val_err:.2f}px | "
              f"誤差<0.5cm: {acc_0_5cm:.2f}% | 誤差<1cm: {acc_1_0cm:.2f}%")

        if val_iou > best_val_iou:
            best_val_iou = val_iou
            early_stop_counter = 0  # reset patience
            torch.save(model.state_dict(), f"checkpoints/unet/unet_{fold}_best.pth")
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print(f"🛑 Early stopping at epoch {epoch+1} for {fold}")
                break

    # 儲存整個驗證集所有預測圖像
    out_dir = f"predictions/unet/{fold}"
    os.makedirs(out_dir, exist_ok=True)
    model.eval()
    count = 1

    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs = imgs.to(device)
            masks = masks.to(device)
            preds = model(imgs)
            preds = (torch.sigmoid(preds) > 0.5).float()

            for i in range(imgs.size(0)):
                orig = to_pil_image(imgs[i][0].cpu())
                gt = to_pil_image(masks[i][0].cpu())
                pred = to_pil_image(preds[i][0].cpu())

                w, h = orig.width, orig.height
                combined = Image.new('L', (w * 3, h))
                combined.paste(orig, (0, 0))
                combined.paste(gt, (w, 0))
                combined.paste(pred, (2 * w, 0))
                combined.save(f"{out_dir}/pred_{count}.png")
                count += 1

print("✅ 使用預訓練 U-Net 完成訓練！")
# Out:
# === 開始訓練 Fold1 ===
# [Fold1 - Epoch 1] Loss: 104.59 | IOU: 0.0963 | 平均誤差: 24.61px | 誤差<0.5cm: 75.00% | 誤差<1cm: 95.83%
# [Fold1 - Epoch 2] Loss: 87.50 | IOU: 0.1057 | 平均誤差: 6.32px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 3] Loss: 81.53 | IOU: 0.1702 | 平均誤差: 7.68px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 4] Loss: 77.02 | IOU: 0.1538 | 平均誤差: 7.21px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 5] Loss: 73.18 | IOU: 0.1897 | 平均誤差: 6.17px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 6] Loss: 68.74 | IOU: 0.1254 | 平均誤差: 7.54px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 7] Loss: 64.31 | IOU: 0.2510 | 平均誤差: 4.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 8] Loss: 60.80 | IOU: 0.2271 | 平均誤差: 8.38px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 9] Loss: 55.62 | IOU: 0.2552 | 平均誤差: 7.96px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 10] Loss: 50.29 | IOU: 0.2911 | 平均誤差: 7.19px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 11] Loss: 44.88 | IOU: 0.2437 | 平均誤差: 5.78px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 12] Loss: 41.08 | IOU: 0.2872 | 平均誤差: 5.82px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 13] Loss: 36.25 | IOU: 0.2814 | 平均誤差: 5.47px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 14] Loss: 32.11 | IOU: 0.2601 | 平均誤差: 7.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 15] Loss: 28.35 | IOU: 0.2882 | 平均誤差: 6.73px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 16] Loss: 26.22 | IOU: 0.1587 | 平均誤差: 7.75px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 17] Loss: 23.33 | IOU: 0.2376 | 平均誤差: 7.59px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 18] Loss: 20.35 | IOU: 0.2443 | 平均誤差: 6.92px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 19] Loss: 18.96 | IOU: 0.1875 | 平均誤差: 7.97px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 20] Loss: 17.66 | IOU: 0.1940 | 平均誤差: 8.73px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 21] Loss: 16.36 | IOU: 0.2002 | 平均誤差: 7.85px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 22] Loss: 15.33 | IOU: 0.1890 | 平均誤差: 7.14px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 23] Loss: 14.10 | IOU: 0.2140 | 平均誤差: 7.09px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch
| 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 19] Loss: 21.98 | IOU: 0.2694 | 平均誤差: 6.40px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 20] Loss: 20.14 | IOU: 0.2873 | 平均誤差: 6.11px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 21] Loss: 18.74 | IOU: 0.2101 | 平均誤差: 7.98px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 22] Loss: 17.49 | IOU: 0.2475 | 平均誤差: 6.55px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 23] Loss: 15.25 | IOU: 0.2224 | 平均誤差: 6.77px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 24] Loss: 14.54 | IOU: 0.2285 | 平均誤差: 6.16px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 25] Loss: 13.93 | IOU: 0.2157 | 平均誤差: 7.70px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 26] Loss: 13.01 | IOU: 0.2944 | 平均誤差: 5.59px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 27] Loss: 12.38 | IOU: 0.2521 | 平均誤差: 6.89px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 28] Loss: 12.57 | IOU: 0.1878 | 平均誤差: 7.83px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 29] Loss: 12.07 | IOU: 0.2743 | 平均誤差: 6.39px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 30] Loss: 11.23 | IOU: 0.1985 | 平均誤差: 7.39px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 31] Loss: 10.73 | IOU: 0.2214 | 平均誤差: 6.29px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 32] Loss: 10.09 | IOU: 0.2253 | 平均誤差: 6.29px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 33] Loss: 10.18 | IOU: 0.2042 | 平均誤差: 7.03px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 34] Loss: 9.52 | IOU: 0.2534 | 平均誤差: 6.14px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 35] Loss: 9.15 | IOU: 0.1598 | 平均誤差: 6.51px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 36] Loss: 9.23 | IOU: 0.2008 | 平均誤差: 7.39px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 37] Loss: 8.82 | IOU: 0.2262 | 平均誤差: 6.48px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 38] Loss: 8.76 | IOU: 0.1872 | 平均誤差: 6.68px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 39] Loss: 7.64 | IOU: 0.2213 | 平均誤差: 7.10px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 40] Loss: 7.67 | IOU: 0.2193 | 平均誤差: 6.67px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 41] Loss: 7.75 | IOU: 0.2340 | 平均誤差: 7.33px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 42] Loss: 7.65 | IOU: 0.2022 | 平均誤差: 7.53px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 43] Loss: 8.02 | IOU: 0.2041 | 平均誤差: 5.55px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 44] Loss: 7.64 | IOU: 0.2434 | 平均誤差: 7.43px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 45] Loss: 7.10 | IOU: 0.2158 | 平均誤差: 7.39px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 46] Loss: 6.70 | IOU: 0.2256 | 平均誤差: 6.22px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 47] Loss: 6.57 | IOU: 0.2058 | 平均誤差: 7.22px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 48] Loss: 6.73 | IOU: 0.2100 | 平均誤差: 7.06px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# 🛑 Early stopping at epoch 48 for Fold3
# === 開始訓練 Fold4 ===
# [Fold4 - Epoch 1] Loss: 108.37 | IOU: 0.0111 | 平均誤差: 15.23px | 誤差<0.5cm: 95.83% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 2] Loss: 91.46 | IOU: 0.0824 | 平均誤差: 31.92px | 誤差<0.5cm: 68.75% | 誤差<1cm: 95.83%
# [Fold4 - Epoch 3] Loss: 83.80 | IOU: 0.1808 | 平均誤差: 7.21px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 4] Loss: 79.14 | IOU: 0.1809 | 平均誤差: 5.97px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 5] Loss: 75.20 | IOU: 0.2040 | 平均誤差: 6.58px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 6] Loss: 70.81 | IOU: 0.1861 | 平均誤差: 4.57px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 7] Loss: 66.08 | IOU: 0.2354 | 平均誤差: 5.58px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 8] Loss: 62.07 | IOU: 0.2099 | 平均誤差: 8.75px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 9] Loss: 57.96 | IOU: 0.2305 | 平均誤差: 3.67px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 10] Loss: 51.49 | IOU: 0.2704 | 平均誤差: 4.48px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 11] Loss: 46.70 | IOU: 0.3046 | 平均誤差: 4.17px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 12] Loss: 42.78 | IOU: 0.2399 | 平均誤差: 7.67px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 13] Loss: 37.98 | IOU: 0.3122 | 平均誤差: 8.57px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 14] Loss: 34.30 | IOU: 0.2648 | 平均誤差: 8.95px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 15] Loss: 31.59 | IOU: 0.3415 | 平均誤差: 6.95px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 16] Loss: 27.73 | IOU: 0.3406 | 平均誤差: 6.31px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 17] Loss: 25.68 | IOU: 0.2539 | 平均誤差: 8.72px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 18] Loss: 21.82 | IOU: 0.2459 | 平均誤差: 10.17px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 19] Loss: 21.25 | IOU: 0.1842 | 平均誤差: 13.26px | 誤差<0.5cm: 95.83% | 誤差<1cm: 95.83%
# [Fold4 - Epoch 20] Loss: 19.96 | IOU: 0.2677 | 平均誤差: 7.34px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 21] Loss: 17.07 | IOU: 0.2143 | 平均誤差: 10.04px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 22] Loss: 15.76 | IOU: 0.2937 | 平均誤差: 10.30px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 23] Loss: 14.75 | IOU: 0.2775 | 平均誤差: 9.69px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 24] Loss: 14.38 | IOU: 0.2648 | 平均誤差: 8.15px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 25] Loss: 12.68 | IOU: 0.2082 | 平均誤差: 8.73px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 26] Loss: 12.27 | IOU: 0.2702 | 平均誤差: 9.61px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 27] Loss: 12.10 | IOU: 0.2092 | 平均誤差: 9.24px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 28] Loss: 11.58 | IOU: 0.2062 | 平均誤差: 12.34px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 29] Loss: 11.48 | IOU: 0.2652 | 平均誤差: 11.25px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 30] Loss: 10.54 | IOU: 0.2777 | 平均誤差: 9.34px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 31] Loss: 10.08 | IOU: 0.1970 | 平均誤差: 12.63px | 誤差<0.5cm: 95.14% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 32] Loss: 9.82 | IOU: 0.2707 | 平均誤差: 11.54px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 33] Loss: 9.42 | IOU: 0.2194 | 平均誤差: 13.14px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 34] Loss: 8.96 | IOU: 0.2627 | 平均誤差: 10.15px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 35] Loss: 9.21 | IOU: 0.2273 | 平均誤差: 12.22px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 36] Loss: 8.25 | IOU: 0.1992 | 平均誤差: 13.88px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 37] Loss: 7.84 | IOU: 0.2207 | 平均誤差: 12.15px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 38] Loss: 8.18 | IOU: 0.2473 | 平均誤差: 10.54px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 39] Loss: 7.64 | IOU: 0.2017 | 平均誤差: 12.44px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 40] Loss: 7.61 | IOU: 0.2438 | 平均誤差: 12.70px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 41] Loss: 7.35 | IOU: 0.1951 | 平均誤差: 12.08px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 42] Loss: 7.08 | IOU: 0.2315 | 平均誤差: 10.81px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 43] Loss: 6.61 | IOU: 0.2048 | 平均誤差: 11.83px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 44] Loss: 6.49 | IOU: 0.1973 | 平均誤差: 12.86px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# [Fold4 - Epoch 45] Loss: 6.34 | IOU: 0.2187 | 平均誤差: 12.22px | 誤差<0.5cm: 97.92% | 誤差<1cm: 97.92%
# 🛑 Early stopping at epoch 45 for Fold4
# === 開始訓練 Fold5 ===
# [Fold5 - Epoch 1] Loss: 96.14 | IOU: 0.1500 | 平均誤差: 10.71px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 2] Loss: 83.01 | IOU: 0.2062 | 平均誤差: 6.07px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 3] Loss: 76.68 | IOU: 0.2145 | 平均誤差: 6.08px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 4] Loss: 72.14 | IOU: 0.2230 | 平均誤差: 7.14px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 5] Loss: 68.14 | IOU: 0.1537 | 平均誤差: 11.85px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 6] Loss: 64.20 | IOU: 0.2536 | 平均誤差: 6.76px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 7] Loss: 59.58 | IOU: 0.2094 | 平均誤差: 5.86px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 8] Loss: 55.54 | IOU: 0.2335 | 平均誤差: 6.08px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 9] Loss: 52.19 | IOU: 0.1775 | 平均誤差: 7.10px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 10] Loss: 46.12 | IOU: 0.2267 | 平均誤差: 7.97px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 11] Loss: 43.14 | IOU: 0.2435 | 平均誤差: 6.84px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 12] Loss: 37.16 | IOU: 0.2294 | 平均誤差: 7.24px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 13] Loss: 35.03 | IOU: 0.2032 | 平均誤差: 7.43px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 14] Loss: 31.56 | IOU: 0.2404 | 平均誤差: 7.56px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 15] Loss: 30.44 | IOU: 0.1936 | 平均誤差: 6.85px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 16] Loss: 25.85 | IOU: 0.1368 | 平均誤差: 6.19px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 17] Loss: 23.29 | IOU: 0.2183 | 平均誤差: 13.55px | 誤差<0.5cm: 97.22% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 18] Loss: 21.32 | IOU: 0.2462 | 平均誤差: 8.98px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 19] Loss: 20.91 | IOU: 0.1875 | 平均誤差: 9.50px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 20] Loss: 17.73 | IOU: 0.1652 | 平均誤差: 9.74px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 21] Loss: 17.44 | IOU: 0.2326 | 平均誤差: 9.07px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 22] Loss: 16.87 | IOU: 0.1843 | 平均誤差: 7.38px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 23] Loss: 15.12 | IOU: 0.1517 | 平均誤差: 9.54px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 24] Loss: 13.65 | IOU: 0.1953 | 平均誤差: 8.07px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 25] Loss: 13.15 | IOU: 0.1897 | 平均誤差: 7.35px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 26] Loss: 13.51 | IOU: 0.1995 | 平均誤差: 8.99px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 27] Loss: 12.67 | IOU: 0.1513 | 平均誤差: 9.75px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 28] Loss: 11.35 | IOU: 0.1420 | 平均誤差: 7.72px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 29] Loss: 10.41 | IOU: 0.1302 | 平均誤差: 9.33px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 30] Loss: 10.76 | IOU: 0.1691 | 平均誤差: 9.62px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 31] Loss: 11.17 | IOU: 0.1596 | 平均誤差: 9.76px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 32] Loss: 10.44 | IOU: 0.1432 | 平均誤差: 8.00px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 33] Loss: 9.98 | IOU: 0.1684 | 平均誤差: 8.13px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 34] Loss: 10.51 | IOU: 0.1958 | 平均誤差: 7.82px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 35] Loss: 9.57 | IOU: 0.1449 | 平均誤差: 9.24px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 36] Loss: 9.09 | IOU: 0.1527 | 平均誤差: 8.11px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# 🛑 Early stopping at epoch 36 for Fold5
# ✅ 使用預訓練 U-Net 完成訓練！
