# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models.segmentation as models
import numpy as np
import matplotlib.pyplot as plt
from dataset import get_loaders
from torchvision.transforms.functional import to_pil_image
from PIL import Image

# ⚙️ 1. 基本設定
device = 'cuda' if torch.cuda.is_available() else 'cpu'
os.makedirs("checkpoints/fcn", exist_ok=True)

# ⚙️ 2. Dice + BCE 混合損失
def dice_loss(pred, target, eps=1e-6):
    pred = torch.sigmoid(pred)
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum()
    return 1 - (2. * intersection + eps) / (union + eps)

def mixed_loss(pred, target):
    bce = nn.BCEWithLogitsLoss()(pred, target)
    return 0.3*bce + 0.7*dice_loss(pred, target)

# ⚙️ 3. 評估指標
def compute_iou(preds, masks, threshold=0.5):
    preds = (torch.sigmoid(preds) > threshold).float()
    intersection = (preds * masks).sum(dim=(1,2,3))
    union = ((preds + masks) > 0).float().sum(dim=(1,2,3))
    return (intersection / (union + 1e-6)).mean().item()

def evaluate_prediction_error(preds, masks, px_per_cm=72):
    preds = (torch.sigmoid(preds) > 0.5).float()
    errors = []
    for i in range(preds.size(0)):
        pred_coords = torch.nonzero(preds[i, 0], as_tuple=False)
        true_coords = torch.nonzero(masks[i, 0], as_tuple=False)
        if len(pred_coords) == 0 or len(true_coords) == 0:
            continue
        pred_y = pred_coords[:, 0].float().mean()
        true_y = true_coords[:, 0].float().mean()
        errors.append(torch.abs(pred_y - true_y).item())

    if not errors:
        return 0, 0, 0
    mean_err = np.mean(errors)
    acc_0_5cm = np.mean(np.array(errors) <= (0.5 * px_per_cm)) * 100
    acc_1_0cm = np.mean(np.array(errors) <= (1.0 * px_per_cm)) * 100
    return mean_err, acc_0_5cm, acc_1_0cm

# ⚙️ 4. 模型載入
def get_model():
    model = models.fcn_resnet50(weights=None, num_classes=1)
    return model


all_folds = ['Fold1', 'Fold2', 'Fold3', 'Fold4', 'Fold5']
for fold in all_folds:
    print(f"=== 開始訓練 {fold} ===")
    train_loader, val_loader = get_loaders('processed_data', fold, batch_size=8)
    model = get_model().to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    best_val_iou = 0
    early_stop_count = 0

    for epoch in range(100):  # 最多訓練 100 次
        model.train()
        total_loss = 0
        for imgs, masks in train_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            outputs = model(imgs)['out']
            loss = mixed_loss(outputs, masks)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        model.eval()
        val_iou = val_err = acc_0_5cm = acc_1_0cm = 0
        with torch.no_grad():
            for imgs, masks in val_loader:
                imgs, masks = imgs.to(device), masks.to(device)
                outputs = model(imgs)['out']
                val_iou += compute_iou(outputs, masks)
                mean_err, a05, a10 = evaluate_prediction_error(outputs, masks)
                val_err += mean_err
                acc_0_5cm += a05
                acc_1_0cm += a10
        val_iou /= len(val_loader)
        val_err /= len(val_loader)
        acc_0_5cm /= len(val_loader)
        acc_1_0cm /= len(val_loader)

        print(f"[{fold} - Epoch {epoch+1}] Loss: {total_loss:.2f} | IOU: {val_iou:.4f} | 平均誤差: {val_err:.2f}px | "
              f"誤差<0.5cm: {acc_0_5cm:.2f}% | 誤差<1cm: {acc_1_0cm:.2f}%")

        if val_iou > best_val_iou:
            best_val_iou = val_iou
            early_stop_count = 0
            torch.save(model.state_dict(), f"checkpoints/fcn/fcn_{fold}_best.pth")
        else:
            early_stop_count += 1

        if early_stop_count >=30:
            print(f"⏹️ 提前停止訓練（early stopping），epoch = {epoch+1}")
            break

    # ⚙️ 儲存預測圖像（只存 predicted mask）
    out_dir = f"predictions/fcn/{fold}"
    os.makedirs(out_dir, exist_ok=True)
    model.eval()
    count = 0
    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs = imgs.to(device)
            masks = masks.to(device)

            # ✅ 從 OrderedDict 中取出 'out'
            preds = model(imgs)['out']

            # ✅ Sigmoid 並二值化
            preds = (torch.sigmoid(preds) > 0.5).float()

            for i in range(imgs.size(0)):
                orig = to_pil_image(imgs[i][0].cpu())
                gt = to_pil_image(masks[i][0].cpu())
                pred = to_pil_image(preds[i][0].cpu())

                w, h = orig.width, orig.height
                combined = Image.new('L', (w * 3, h))
                combined.paste(orig, (0, 0))
                combined.paste(gt, (w, 0))
                combined.paste(pred, (2 * w, 0))
                combined.save(f"{out_dir}/pred_{count}.png")
                count += 1
# Out:
# === 開始訓練 Fold1 ===
# [Fold1 - Epoch 1] Loss: 86.97 | IOU: 0.1795 | 平均誤差: 11.40px | 誤差<0.5cm: 95.83% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 2] Loss: 68.80 | IOU: 0.2465 | 平均誤差: 7.91px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 3] Loss: 61.15 | IOU: 0.2404 | 平均誤差: 6.25px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 4] Loss: 54.26 | IOU: 0.2541 | 平均誤差: 5.27px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 5] Loss: 46.80 | IOU: 0.2399 | 平均誤差: 7.27px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 6] Loss: 40.67 | IOU: 0.2554 | 平均誤差: 6.29px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 7] Loss: 35.15 | IOU: 0.1881 | 平均誤差: 6.25px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 8] Loss: 30.22 | IOU: 0.2044 | 平均誤差: 7.58px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 9] Loss: 25.58 | IOU: 0.2258 | 平均誤差: 8.21px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 10] Loss: 22.18 | IOU: 0.2047 | 平均誤差: 6.06px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 11] Loss: 20.50 | IOU: 0.2280 | 平均誤差: 7.70px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 12] Loss: 18.17 | IOU: 0.2463 | 平均誤差: 6.33px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 13] Loss: 16.33 | IOU: 0.2230 | 平均誤差: 7.34px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 14] Loss: 14.46 | IOU: 0.2139 | 平均誤差: 9.79px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 15] Loss: 13.82 | IOU: 0.2046 | 平均誤差: 6.73px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 16] Loss: 12.76 | IOU: 0.1874 | 平均誤差: 9.51px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 17] Loss: 11.86 | IOU: 0.2103 | 平均誤差: 8.53px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 18] Loss: 11.18 | IOU: 0.1919 | 平均誤差: 7.74px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 19] Loss: 10.49 | IOU: 0.1998 | 平均誤差: 8.60px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 20] Loss: 9.78 | IOU: 0.1941 | 平均誤差: 5.77px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 21] Loss: 9.18 | IOU: 0.1861 | 平均誤差: 8.59px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 22] Loss: 8.86 | IOU: 0.2093 | 平均誤差: 6.61px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 23] Loss: 8.65 | IOU: 0.1924 | 平均誤差: 7.66px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 24] Loss: 7.94 | IOU: 0.1774 | 平均誤差: 8.22px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 25] Loss: 7.67 | IOU: 0.1926 | 平均誤差: 7.22px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 26] Loss: 7.10 | IOU: 0.2156 | 平均誤差: 6.58px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 27] Loss: 6.88 | IOU: 0.2166 | 平均誤差: 7.51px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 28] Loss: 6.67 | IOU: 0.2282 | 平均誤差: 6.44px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 29] Loss: 6.65 | IOU: 0.1748 | 平均誤差: 8.91px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 30] Loss: 6.29 | IOU: 0.1969 | 平均誤差: 7.07px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 31] Loss: 6.18 | IOU: 0.1898 | 平均誤差: 7.21px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 32] Loss: 6.11 | IOU: 0.2310 | 平均誤差: 7.25px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 33] Loss: 5.79 | IOU: 0.1952 | 平均誤差: 8.84px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 34] Loss: 5.64 | IOU: 0.1792 | 平均誤差: 9.00px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 35] Loss: 5.50 | IOU: 0.1938 | 平均誤差: 7.12px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold1 - Epoch 36] Loss: 5.42 | IOU: 0.1757 | 平均誤差: 7.53px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# ⏹️ 提前停止訓練（early stopping），epoch = 36
# === 開始訓練 Fold2 ===
# [Fold2 - Epoch 1] Loss: 88.52 | IOU: 0.2204 | 平均誤差: 10.42px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 2] Loss: 69.39 | IOU: 0.2545 | 平均誤差: 5.84px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 3] Loss: 62.34 | IOU: 0.2148 | 平均誤差: 9.62px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 4] Loss: 55.46 | IOU: 0.2364 | 平均誤差: 10.90px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 5] Loss: 48.07 | IOU: 0.2438 | 平均誤差: 5.17px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 6] Loss: 41.29 | IOU: 0.2708 | 平均誤差: 8.26px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 7] Loss: 37.78 | IOU: 0.2505 | 平均誤差: 9.02px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 8] Loss: 31.01 | IOU: 0.2104 | 平均誤差: 5.88px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 9] Loss: 26.97 | IOU: 0.2317 | 平均誤差: 8.71px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 10] Loss: 23.73 | IOU: 0.2477 | 平均誤差: 6.68px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 11] Loss: 21.14 | IOU: 0.2278 | 平均誤差: 6.23px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 12] Loss: 19.71 | IOU: 0.1796 | 平均誤差: 7.60px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 13] Loss: 17.36 | IOU: 0.1531 | 平均誤差: 7.37px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 14] Loss: 15.64 | IOU: 0.2068 | 平均誤差: 6.51px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 15] Loss: 14.46 | IOU: 0.2321 | 平均誤差: 4.78px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 16] Loss: 13.39 | IOU: 0.2076 | 平均誤差: 6.81px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 17] Loss: 12.65 | IOU: 0.1813 | 平均誤差: 6.05px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 18] Loss: 11.59 | IOU: 0.2080 | 平均誤差: 6.09px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 19] Loss: 10.42 | IOU: 0.2026 | 平均誤差: 5.66px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 20] Loss: 9.96 | IOU: 0.1659 | 平均誤差: 6.73px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 21] Loss: 9.55 | IOU: 0.1970 | 平均誤差: 5.61px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 22] Loss: 8.97 | IOU: 0.1540 | 平均誤差: 7.35px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 23] Loss: 8.56 | IOU: 0.1983 | 平均誤差: 6.54px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 24] Loss: 8.16 | IOU: 0.1963 | 平均誤差: 6.07px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 25] Loss: 7.89 | IOU: 0.1522 | 平均誤差: 7.42px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 26] Loss: 7.59 | IOU: 0.1937 | 平均誤差: 6.64px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 27] Loss: 7.18 | IOU: 0.1838 | 平均誤差: 6.24px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 28] Loss: 6.80 | IOU: 0.1883 | 平均誤差: 7.25px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 29] Loss: 6.37 | IOU: 0.2091 | 平均誤差: 5.70px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 30] Loss: 6.08 | IOU: 0.1938 | 平均誤差: 7.21px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 31] Loss: 5.98 | IOU: 0.2244 | 平均誤差: 6.12px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 32] Loss: 5.91 | IOU: 0.1682 | 平均誤差: 6.41px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 33] Loss: 5.74 | IOU: 0.1973 | 平均誤差: 6.88px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 34] Loss: 5.59 | IOU: 0.1968 | 平均誤差: 6.72px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 35] Loss: 5.52 | IOU: 0.2204 | 平均誤差: 6.30px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold2 - Epoch 36] Loss: 5.51 | IOU: 0.2062 | 平均誤差: 7.08px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# ⏹️ 提前停止訓練（early stopping），epoch = 36
# === 開始訓練 Fold3 ===
# [Fold3 - Epoch 1] Loss: 88.35 | IOU: 0.2208 | 平均誤差: 6.16px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 2] Loss: 68.17 | IOU: 0.2302 | 平均誤差: 5.10px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 3] Loss: 60.15 | IOU: 0.2607 | 平均誤差: 5.61px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 4] Loss: 53.85 | IOU: 0.1236 | 平均誤差: 8.96px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 5] Loss: 46.41 | IOU: 0.3127 | 平均誤差: 5.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 6] Loss: 40.29 | IOU: 0.2402 | 平均誤差: 7.64px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 7] Loss: 36.15 | IOU: 0.2728 | 平均誤差: 6.15px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 8] Loss: 30.52 | IOU: 0.1966 | 平均誤差: 5.80px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 9] Loss: 26.47 | IOU: 0.1910 | 平均誤差: 9.24px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 10] Loss: 22.95 | IOU: 0.2132 | 平均誤差: 5.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 11] Loss: 20.48 | IOU: 0.2637 | 平均誤差: 6.45px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 12] Loss: 18.16 | IOU: 0.2474 | 平均誤差: 5.97px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 13] Loss: 16.45 | IOU: 0.2385 | 平均誤差: 6.04px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 14] Loss: 15.43 | IOU: 0.2397 | 平均誤差: 6.77px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 15] Loss: 14.33 | IOU: 0.2639 | 平均誤差: 6.78px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 16] Loss: 12.98 | IOU: 0.2413 | 平均誤差: 6.27px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 17] Loss: 11.61 | IOU: 0.2355 | 平均誤差: 8.54px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 18] Loss: 10.86 | IOU: 0.2151 | 平均誤差: 5.54px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 19] Loss: 10.27 | IOU: 0.2246 | 平均誤差: 8.48px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 20] Loss: 9.91 | IOU: 0.2301 | 平均誤差: 8.55px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 21] Loss: 9.54 | IOU: 0.2154 | 平均誤差: 7.19px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 22] Loss: 9.04 | IOU: 0.2422 | 平均誤差: 6.70px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 23] Loss: 8.38 | IOU: 0.2021 | 平均誤差: 9.59px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 24] Loss: 8.09 | IOU: 0.2387 | 平均誤差: 6.92px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 25] Loss: 7.48 | IOU: 0.2040 | 平均誤差: 6.38px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 26] Loss: 7.27 | IOU: 0.2073 | 平均誤差: 8.21px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 27] Loss: 7.19 | IOU: 0.1969 | 平均誤差: 9.26px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 28] Loss: 7.04 | IOU: 0.2252 | 平均誤差: 6.58px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 29] Loss: 6.53 | IOU: 0.1935 | 平均誤差: 6.81px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 30] Loss: 6.41 | IOU: 0.2108 | 平均誤差: 7.82px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 31] Loss: 6.20 | IOU: 0.2245 | 平均誤差: 8.31px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 32] Loss: 6.06 | IOU: 0.2043 | 平均誤差: 9.42px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 33] Loss: 5.89 | IOU: 0.2001 | 平均誤差: 6.78px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 34] Loss: 5.84 | IOU: 0.2227 | 平均誤差: 8.33px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold3 - Epoch 35] Loss: 5.67 | IOU: 0.2106 | 平均誤差: 6.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# ⏹️ 提前停止訓練（early stopping），epoch = 35
# === 開始訓練 Fold4 ===
# [Fold4 - Epoch 1] Loss: 86.65 | IOU: 0.2129 | 平均誤差: 4.19px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 2] Loss: 67.93 | IOU: 0.2644 | 平均誤差: 3.94px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 3] Loss: 59.56 | IOU: 0.2519 | 平均誤差: 4.85px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 4] Loss: 53.64 | IOU: 0.2935 | 平均誤差: 4.39px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 5] Loss: 45.21 | IOU: 0.2737 | 平均誤差: 4.64px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 6] Loss: 41.34 | IOU: 0.2621 | 平均誤差: 5.71px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 7] Loss: 36.27 | IOU: 0.2451 | 平均誤差: 7.16px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 8] Loss: 33.61 | IOU: 0.2500 | 平均誤差: 6.67px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 9] Loss: 28.41 | IOU: 0.1692 | 平均誤差: 7.90px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 10] Loss: 25.59 | IOU: 0.1428 | 平均誤差: 14.27px | 誤差<0.5cm: 97.22% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 11] Loss: 23.46 | IOU: 0.1400 | 平均誤差: 11.65px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 12] Loss: 19.69 | IOU: 0.1504 | 平均誤差: 11.41px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 13] Loss: 17.63 | IOU: 0.2520 | 平均誤差: 7.08px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 14] Loss: 15.66 | IOU: 0.1536 | 平均誤差: 11.41px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 15] Loss: 14.05 | IOU: 0.2017 | 平均誤差: 8.81px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 16] Loss: 13.43 | IOU: 0.1847 | 平均誤差: 11.78px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 17] Loss: 12.41 | IOU: 0.1814 | 平均誤差: 10.30px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 18] Loss: 11.55 | IOU: 0.2120 | 平均誤差: 9.18px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 19] Loss: 11.63 | IOU: 0.2108 | 平均誤差: 7.35px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 20] Loss: 10.01 | IOU: 0.1894 | 平均誤差: 9.93px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 21] Loss: 9.23 | IOU: 0.1608 | 平均誤差: 10.47px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 22] Loss: 8.78 | IOU: 0.1484 | 平均誤差: 10.80px | 誤差<0.5cm: 97.22% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 23] Loss: 8.37 | IOU: 0.1585 | 平均誤差: 9.76px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 24] Loss: 7.74 | IOU: 0.1478 | 平均誤差: 9.80px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 25] Loss: 7.58 | IOU: 0.1663 | 平均誤差: 9.61px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 26] Loss: 7.50 | IOU: 0.1458 | 平均誤差: 10.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 27] Loss: 7.36 | IOU: 0.2000 | 平均誤差: 8.79px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 28] Loss: 7.23 | IOU: 0.1521 | 平均誤差: 9.78px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 29] Loss: 6.83 | IOU: 0.1575 | 平均誤差: 9.23px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 30] Loss: 6.72 | IOU: 0.1469 | 平均誤差: 9.31px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 31] Loss: 6.50 | IOU: 0.1804 | 平均誤差: 9.56px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 32] Loss: 6.27 | IOU: 0.1876 | 平均誤差: 10.05px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 33] Loss: 6.32 | IOU: 0.1467 | 平均誤差: 10.22px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold4 - Epoch 34] Loss: 5.92 | IOU: 0.1679 | 平均誤差: 8.94px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# ⏹️ 提前停止訓練（early stopping），epoch = 34
# === 開始訓練 Fold5 ===
# [Fold5 - Epoch 1] Loss: 90.11 | IOU: 0.1365 | 平均誤差: 14.39px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 2] Loss: 68.68 | IOU: 0.2239 | 平均誤差: 8.99px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 3] Loss: 62.17 | IOU: 0.2109 | 平均誤差: 6.40px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 4] Loss: 56.19 | IOU: 0.2757 | 平均誤差: 7.26px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 5] Loss: 48.79 | IOU: 0.2482 | 平均誤差: 6.26px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 6] Loss: 43.09 | IOU: 0.3125 | 平均誤差: 5.20px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 7] Loss: 37.45 | IOU: 0.2837 | 平均誤差: 7.54px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 8] Loss: 32.18 | IOU: 0.2718 | 平均誤差: 7.35px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 9] Loss: 28.75 | IOU: 0.2970 | 平均誤差: 8.80px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 10] Loss: 24.97 | IOU: 0.3289 | 平均誤差: 6.68px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 11] Loss: 22.94 | IOU: 0.2449 | 平均誤差: 9.39px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 12] Loss: 19.83 | IOU: 0.2469 | 平均誤差: 12.63px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 13] Loss: 18.54 | IOU: 0.2389 | 平均誤差: 11.25px | 誤差<0.5cm: 93.75% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 14] Loss: 16.78 | IOU: 0.2343 | 平均誤差: 11.22px | 誤差<0.5cm: 95.83% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 15] Loss: 15.45 | IOU: 0.2081 | 平均誤差: 14.05px | 誤差<0.5cm: 95.83% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 16] Loss: 14.67 | IOU: 0.2215 | 平均誤差: 11.50px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 17] Loss: 13.48 | IOU: 0.1884 | 平均誤差: 10.88px | 誤差<0.5cm: 95.83% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 18] Loss: 11.87 | IOU: 0.2458 | 平均誤差: 10.96px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 19] Loss: 10.77 | IOU: 0.2130 | 平均誤差: 8.39px | 誤差<0.5cm: 100.00% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 20] Loss: 9.95 | IOU: 0.2454 | 平均誤差: 7.97px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 21] Loss: 9.52 | IOU: 0.2309 | 平均誤差: 8.78px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 22] Loss: 9.09 | IOU: 0.2313 | 平均誤差: 8.84px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 23] Loss: 8.61 | IOU: 0.2123 | 平均誤差: 9.16px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 24] Loss: 8.20 | IOU: 0.2578 | 平均誤差: 10.53px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 25] Loss: 7.62 | IOU: 0.2198 | 平均誤差: 6.85px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 26] Loss: 7.20 | IOU: 0.2116 | 平均誤差: 9.02px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 27] Loss: 7.06 | IOU: 0.2027 | 平均誤差: 9.89px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 28] Loss: 6.94 | IOU: 0.1788 | 平均誤差: 12.50px | 誤差<0.5cm: 95.83% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 29] Loss: 6.58 | IOU: 0.1891 | 平均誤差: 7.56px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 30] Loss: 6.25 | IOU: 0.1826 | 平均誤差: 8.53px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 31] Loss: 6.35 | IOU: 0.2287 | 平均誤差: 9.78px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 32] Loss: 6.12 | IOU: 0.1831 | 平均誤差: 10.03px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 33] Loss: 5.86 | IOU: 0.1931 | 平均誤差: 10.89px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 34] Loss: 5.83 | IOU: 0.1789 | 平均誤差: 10.35px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 35] Loss: 5.85 | IOU: 0.1976 | 平均誤差: 10.15px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 36] Loss: 5.62 | IOU: 0.1757 | 平均誤差: 10.85px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 37] Loss: 5.49 | IOU: 0.1635 | 平均誤差: 9.40px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 38] Loss: 5.39 | IOU: 0.1733 | 平均誤差: 11.15px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 39] Loss: 5.33 | IOU: 0.1868 | 平均誤差: 9.61px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# [Fold5 - Epoch 40] Loss: 5.56 | IOU: 0.1927 | 平均誤差: 10.20px | 誤差<0.5cm: 97.92% | 誤差<1cm: 100.00%
# ⏹️ 提前停止訓練（early stopping），epoch = 40
